# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Location                     0
# Education                    0
# Occupation                   0
# Primary_App                107
# Secondary_Apps             114
# Usage_Frequency              0
# Daily_Usage_Time             0
# Reason_for_Using             0
# Satisfaction                 0
# Challenges                 117
# Desired_Features             0
# Preferred_Communication      0
# Partner_Priorities           0
# dtype: int64

# %%
df["Primary_App"] = df["Primary_App"].fillna(df["Secondary_Apps"])

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Location                     0
# Education                    0
# Occupation                   0
# Primary_App                 31
# Secondary_Apps             114
# Usage_Frequency              0
# Daily_Usage_Time             0
# Reason_for_Using             0
# Satisfaction                 0
# Challenges                 117
# Desired_Features             0
# Preferred_Communication      0
# Partner_Priorities           0
# dtype: int64

# %%
df["Primary_App"] = df["Primary_App"].fillna("None")

# %%
df["Secondary_Apps"] = df["Secondary_Apps"].fillna("None")

# %%
df.head(19)
# Out:
#     User_ID  Age      Gender   Location      Education     Occupation  \
# 0         1   20  Non-binary  Bangalore  Undergraduate     Freelancer
# 1         2   24      Female      Delhi  Undergraduate  Part-time Job
# 2         3   24  Non-binary    Kolkata  Undergraduate         Intern
# 3         4   22  Non-binary      Delhi       Graduate  Full-time Job
# 4         5   18        Male      Delhi       Graduate         Intern
# 5         6   23      Female     Mumbai  Undergraduate        Student
# 6         7   22  Non-binary    Chennai   Postgraduate  Part-time Job
# 7         8   21      Female       Pune   Postgraduate     Freelancer
# 8         9   20        Male       Pune   Postgraduate  Part-time Job
# 9        10   20  Non-binary    Chennai  Undergraduate         Intern
# 10       11   18      Female  Hyderabad   Postgraduate  Full-time Job
# 11       12   21        Male      Delhi  Undergraduate  Part-time Job
# ...

# %%
df["Challenges"] = df["Challenges"].fillna("None")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_cols = ["Gender", "Location", "Education", "Occupation", "Primary_App", 
                    "Secondary_Apps", "Usage_Frequency", "Reason_for_Using", 
                    "Challenges", "Desired_Features", "Preferred_Communication"]
for col in categorical_cols:
    df[col] = df[col].astype(str).str.lower().str.strip()

# %%
df.head(5)
# Out:
#    User_ID  Age      Gender   Location      Education     Occupation  \
# 0        1   20  non-binary  bangalore  undergraduate     freelancer
# 1        2   24      female      delhi  undergraduate  part-time job
# 2        3   24  non-binary    kolkata  undergraduate         intern
# 3        4   22  non-binary      delhi       graduate  full-time job
# 4        5   18        male      delhi       graduate         intern
#
#   Primary_App Secondary_Apps Usage_Frequency  Daily_Usage_Time  \
# 0       hinge          hinge         monthly               NaN
# 1       hinge        okcupid          weekly               NaN
# 2        none           none          weekly               NaN
# 3     okcupid        okcupid           daily               NaN
# 4     okcupid        okcupid          weekly               NaN
#
#     Reason_for_Using  Satisfaction       Challenges    Desired_Features  \
# 0  finding a partner             4  safety concerns         audio calls
# ...

# %%
df = pd.read_csv("GenZ_DatingApp_Data.csv")

# %%
df.isnull().sum()
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Location                     0
# Education                    0
# Occupation                   0
# Primary_App                107
# Secondary_Apps             114
# Usage_Frequency              0
# Daily_Usage_Time             0
# Reason_for_Using             0
# Satisfaction                 0
# Challenges                 117
# Desired_Features             0
# Preferred_Communication      0
# Partner_Priorities           0
# dtype: int64

# %%
df["Primary_App"] = df["Primary_App"].fillna(df["Secondary_Apps"])

# %%
df["Primary_App"] = df["Primary_App"].fillna("None")

# %%
df["Secondary_Apps"] = df["Secondary_Apps"].fillna("None")

# %%
df["Challenges"] = df["Challenges"].fillna("None")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
categorical_cols = ["Gender", "Location", "Education", "Occupation", "Primary_App", 
                    "Secondary_Apps", "Usage_Frequency", "Reason_for_Using", 
                    "Challenges", "Desired_Features", "Preferred_Communication"]
for col in categorical_cols:
    df[col] = df[col].astype(str).str.lower().str.strip()

# %%
df["Daily_Usage_Time"] = df["Daily_Usage_Time"].replace({"30 minutes": 0.5, "1.5 hours": 1.5, "2 hours": 2, "3 hours": 3, "1 hour": 1})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15024\729394960.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Daily_Usage_Time"] = df["Daily_Usage_Time"].replace({"30 minutes": 0.5, "1.5 hours": 1.5, "2 hours": 2, "3 hours": 3, "1 hour": 1})

# %%
df.head(10)
# Out:
#    User_ID  Age      Gender   Location      Education     Occupation  \
# 0        1   20  non-binary  bangalore  undergraduate     freelancer
# 1        2   24      female      delhi  undergraduate  part-time job
# 2        3   24  non-binary    kolkata  undergraduate         intern
# 3        4   22  non-binary      delhi       graduate  full-time job
# 4        5   18        male      delhi       graduate         intern
# 5        6   23      female     mumbai  undergraduate        student
# 6        7   22  non-binary    chennai   postgraduate  part-time job
# 7        8   21      female       pune   postgraduate     freelancer
# 8        9   20        male       pune   postgraduate  part-time job
# 9       10   20  non-binary    chennai  undergraduate         intern
#
#   Primary_App Secondary_Apps Usage_Frequency Daily_Usage_Time  \
# 0       hinge          hinge         monthly           1 hour
# 1       hinge        okcupid          weekly              0.5
# ...

# %%
df["Daily_Usage_Time"] = df["Daily_Usage_Time"].replace({"30 minutes": 0.5, "1.5 hours": 1.5, "2 hours": 2, "3 hours": 3, "1 hour": 1})

# %%
df.head(5)
# Out:
#    User_ID  Age      Gender   Location      Education     Occupation  \
# 0        1   20  non-binary  bangalore  undergraduate     freelancer
# 1        2   24      female      delhi  undergraduate  part-time job
# 2        3   24  non-binary    kolkata  undergraduate         intern
# 3        4   22  non-binary      delhi       graduate  full-time job
# 4        5   18        male      delhi       graduate         intern
#
#   Primary_App Secondary_Apps Usage_Frequency  Daily_Usage_Time  \
# 0       hinge          hinge         monthly               1.0
# 1       hinge        okcupid          weekly               0.5
# 2        none           none          weekly               2.0
# 3     okcupid        okcupid           daily               0.5
# 4     okcupid        okcupid          weekly               2.0
#
#     Reason_for_Using  Satisfaction       Challenges    Desired_Features  \
# 0  finding a partner             4  safety concerns         audio calls
# ...

# %%
df.to_csv("Version 1 Cleaned_GenZ_DatingApp_Data.csv", index=False)

# %%
Questions For Students
Task 1
Are there any duplicate rows? If yes, why might duplicates exist in this dataset? : There are no duplicate rows in the dataset.
Are there inconsistencies in categorical values (e.g., spelling variations, case sensitivity)? : The dataset is consistent in terms of case sensitivity (all values appear to be lowercase).
No obvious spelling variations were found. 
What should we do if a column has too many missing values? : We drop the column because if the missing values are too many it cause us to get wrong information from the dataset 
• Are there outliers in numerical columns? If so, should we remove or adjust them? We remove them
